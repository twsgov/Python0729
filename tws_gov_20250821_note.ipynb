# %% [markdown]
# <a href="https://colab.research.google.com/github/twsgov/Python0729/blob/main/tws_gov_20250821_note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
scores = [20, 65, 30, 40]
print(scores[-4])
print(max(scores), min(scores), sum(scores))
print(len(scores))

# print(scores[len(scores)-1])
# 正向編號 0 1 2 3
# 反向編號-4-3-2-1
print(scores[-1])
# Out:
# 20
# 65 20 155
# 4
# 40

# %%
scores = [80, 65, 20, 30]
count = 0
i = 0
while i < len(scores):
    # !!!! [0 1 2 3] 這個寫法不好的點是
    # 以後如果那個群集型態 他的key不是0 1 2 3
    s = scores[i]
    if s >= 60:
        count = count + 1
    i = i + 1
print(count)
# Out:
# 2

# %%
scores = [80, 65, 20, 30]
count = 0
# for 名稱 in 群(str/dict/list)
for s in scores:
    if s >= 60:
        count = count + 1
print(count)
# Out:
# 2

# %%
# 1+...+10
total = 0
# 1. 次數<後面 2. i=0...次-1
i = 0
while i < 10:
    total = total + (i + 1)
    print(total)
    i = i + 1
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
#range(10)
total = 0
for i in range(10):
    total = total + (i+1)
    print(total)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
scores = [80, 65, 20, 30]
count = 0
# for 名稱 in 群(str/dict/list)
for s in scores:
    if s >= 60:
        count = count + 1
print(count)

2

# 1+...+10
total = 0
# 1. 次數<後面 2. i=0...次-1
i = 0
while i < 10:
    total = total + (i + 1)
    print(total)
    i = i + 1


# range(10) -> [0, 1, 2....9]
total = 0
# 1. 次數range裡面 2. i=0...次-1
for i in range(10):
    total = total + (i + 1)
    print(total)

# %% [markdown]
# #``固定次數`for i in range()
# # for 名稱 in 一群
# # 其他條件：while True +
# ```

# %%
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW"
f = req.urlopen(url)
content = f.read()
print(content)
# Out:
# b'{"data":{"danmu":[{"text":"\\u4e8c\\u5237","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":42903755,"userid":"qaz1210731"},{"text":"\\u5409\\u4f0a\\u5361\\u54c7\\uff01","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":45641971,"userid":"dodylee0107"},{"text":"\\u611f\\u8b1d\\u52d5\\u756b\\u760b\\uff01","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":45796240,"userid":"hyg125"},{"text":"\\u5409\\u4f9d\\u597d\\u53ef\\u611b","color":"#FFFFFF","size":1,"position":0,"time":5,"sn":40580321,"userid":"KingOrange69"},{"text":"\\u54c8\\u560d","color":"#FFFFFF","size":1,"position":0,"time":5,"sn":40657118,"userid":"rwan123"},{"text":"\\u7c3d","color":"#FFFFFF","size":1,"position":0,"time":5,"sn":41446388,"userid":"nehsh101"},{"text":"1","color":"#FFFFFF","size":1,"position":0,"time":5,"sn":42235007,"userid":"zxc520031"},{"text":"\\u500b","color":"#FFFFFF","size":1,"position":0,"time":5,"sn":42576215,"userid":"d3498115"},{"text":"\\u5343","color":"#FFFFFF","size":1,"position":
# ...
